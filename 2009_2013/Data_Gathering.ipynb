# %%
import pandas as pd

data = {
    'Federal': {
        'General/M&P/Investment': [19.00, 18.00, 16.50, 15.00, 15.00],
        'Small business': [11.00, 11.00, 11.00, 11.00, 11.00],
        'Investment - CCPC': [34.67, 34.67, 34.67, 34.67, 34.67]
    },
    'British Columbia': {
        'General/M&P/Investment': [11, 10.5, 10, 10, 10],
        'Small business': [2.5, 2.5, 2.5, 2.5, 2.5]
    },
    'Alberta': {
        'General/M&P/Investment': [10, 10, 10, 10, 10],
        'Small business': [3, 3, 3, 3, 3]
    },
    'Saskatchewan': {
        'General/Investment': [12, 12, 12, 12, 12],
        'Small business': [4.5, 4.5, 4.5, 2, 2],
        'M&P': [10, 10, 10, 10, 10]
    },
    'Manitoba': {
        'General/M&P/Investment': [13, 12, 12, 12, 12],
        'Small business': [1, 1, 0, 0, 0]
    },
    'Ontario': {
        'General/Investment': [14, 12, 11.5, 11.5, 11.5],
        'Small business': [5.5, 4.5, 4.5, 4.5, 4.5],
        'M&P': [12, 10, 10, 10, 10]
    },
    'Quebec': {
        'General/M&P': [11.9, 11.9, 11.9, 11.9, 11.9],
        'Small business': [8, 8, 8, 8, 8],
        'Investment': [11.9, 11.9, 11.9, 11.9, 11.9]
    },
    'New Brunswick': {
        'General/M&P/Investment': [13, 12, 11, 10, 10],
        'Small business': [5, 5, 5, 4.5, 4.5]
    },
    'Nova Scotia': {
        'General/M&P/Investment': [16, 16, 16, 16, 16],
        'Small business': [5, 5, 4.5, 4, 3.5]
    },
    'Prince Edward Island': {
        'General/Investment/M&P': [16, 16, 16, 16, 16],
        'Small business': [3.2, 2.1, 1, 1, 1]
    },
    'Newfoundland and Labrador': {
        'General/Investment': [14, 14, 14, 14, 14],
        'Small business': [5, 4, 4, 4, 4],
        'M&P': [5, 5, 5, 5, 5]
    },
    'Yukon': {
        'General/Investment': [15, 15, 15, 15, 15],
        'Small business': [4, 4, 4, 4, 4],
        'M&P': [2.5, 2.5, 2.5, 2.5, 2.5]
    },
    'Northwest Territories': {
        'General/M&P/Investment': [11.5, 11.5, 11.5, 11.5, 11.5],
        'Small business': [4, 4, 4, 4, 4]
    },
    'Nunavut': {
        'General/M&P/Investment': [12, 12, 12, 12, 12],
        'Small business': [4, 4, 4, 4, 4]
    }
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict({(i,j): data[i][j] 
                           for i in data.keys() 
                           for j in data[i].keys()},
                       orient='index')

df
# Out:
#                                                      0      1      2      3  \
# (Federal, General/M&P/Investment)                19.00  18.00  16.50  15.00
# (Federal, Small business)                        11.00  11.00  11.00  11.00
# (Federal, Investment - CCPC)                     34.67  34.67  34.67  34.67
# (British Columbia, General/M&P/Investment)       11.00  10.50  10.00  10.00
# (British Columbia, Small business)                2.50   2.50   2.50   2.50
# (Alberta, General/M&P/Investment)                10.00  10.00  10.00  10.00
# (Alberta, Small business)                         3.00   3.00   3.00   3.00
# (Saskatchewan, General/Investment)               12.00  12.00  12.00  12.00
# (Saskatchewan, Small business)                    4.50   4.50   4.50   2.00
# (Saskatchewan, M&P)                              10.00  10.00  10.00  10.00
# (Manitoba, General/M&P/Investment)               13.00  12.00  12.00  12.00
# ...

# %%
df.reset_index(drop=False, inplace=True)
df
# Out:
#                                               index      0      1      2  \
# 0                 (Federal, General/M&P/Investment)  19.00  18.00  16.50
# 1                         (Federal, Small business)  11.00  11.00  11.00
# 2                      (Federal, Investment - CCPC)  34.67  34.67  34.67
# 3        (British Columbia, General/M&P/Investment)  11.00  10.50  10.00
# 4                (British Columbia, Small business)   2.50   2.50   2.50
# 5                 (Alberta, General/M&P/Investment)  10.00  10.00  10.00
# 6                         (Alberta, Small business)   3.00   3.00   3.00
# 7                (Saskatchewan, General/Investment)  12.00  12.00  12.00
# 8                    (Saskatchewan, Small business)   4.50   4.50   4.50
# 9                               (Saskatchewan, M&P)  10.00  10.00  10.00
# 10               (Manitoba, General/M&P/Investment)  13.00  12.00  12.00
# 11                       (Manitoba, Small business)   1.00   1.00   0.00
# ...

# %%
df.rename(columns={'index': 'Province'}, inplace=True)
df
# Out:
#                                            Province      0      1      2  \
# 0                 (Federal, General/M&P/Investment)  19.00  18.00  16.50
# 1                         (Federal, Small business)  11.00  11.00  11.00
# 2                      (Federal, Investment - CCPC)  34.67  34.67  34.67
# 3        (British Columbia, General/M&P/Investment)  11.00  10.50  10.00
# 4                (British Columbia, Small business)   2.50   2.50   2.50
# 5                 (Alberta, General/M&P/Investment)  10.00  10.00  10.00
# 6                         (Alberta, Small business)   3.00   3.00   3.00
# 7                (Saskatchewan, General/Investment)  12.00  12.00  12.00
# 8                    (Saskatchewan, Small business)   4.50   4.50   4.50
# 9                               (Saskatchewan, M&P)  10.00  10.00  10.00
# 10               (Manitoba, General/M&P/Investment)  13.00  12.00  12.00
# 11                       (Manitoba, Small business)   1.00   1.00   0.00
# ...

# %%
df.rename(columns={0: '2009', 1: '2010', 2: '2011', 3: '2012', 4: '2013'}, inplace=True)
df
# Out:
#                                            Province   2009   2010   2011  \
# 0                 (Federal, General/M&P/Investment)  19.00  18.00  16.50
# 1                         (Federal, Small business)  11.00  11.00  11.00
# 2                      (Federal, Investment - CCPC)  34.67  34.67  34.67
# 3        (British Columbia, General/M&P/Investment)  11.00  10.50  10.00
# 4                (British Columbia, Small business)   2.50   2.50   2.50
# 5                 (Alberta, General/M&P/Investment)  10.00  10.00  10.00
# 6                         (Alberta, Small business)   3.00   3.00   3.00
# 7                (Saskatchewan, General/Investment)  12.00  12.00  12.00
# 8                    (Saskatchewan, Small business)   4.50   4.50   4.50
# 9                               (Saskatchewan, M&P)  10.00  10.00  10.00
# 10               (Manitoba, General/M&P/Investment)  13.00  12.00  12.00
# 11                       (Manitoba, Small business)   1.00   1.00   0.00
# ...

# %%
import pandas as pd


def filter_general_rows(df):
    # Ensure the first column is treated as strings
    df.iloc[:, 0] = df.iloc[:, 0].astype(str)
    # Filter rows where the first column contains the word "General"
    filtered_df = df[df.iloc[:, 0].str.contains(r'\bGeneral\b', case=False, na=False)]
    return filtered_df


filtered_df = filter_general_rows(df)
filtered_df
# Out:
#                                              Province  2009  2010  2011  2012  \
# 0               ('Federal', 'General/M&P/Investment')  19.0  18.0  16.5  15.0
# 3      ('British Columbia', 'General/M&P/Investment')  11.0  10.5  10.0  10.0
# 5               ('Alberta', 'General/M&P/Investment')  10.0  10.0  10.0  10.0
# 7              ('Saskatchewan', 'General/Investment')  12.0  12.0  12.0  12.0
# 10             ('Manitoba', 'General/M&P/Investment')  13.0  12.0  12.0  12.0
# 12                  ('Ontario', 'General/Investment')  14.0  12.0  11.5  11.5
# 15                          ('Quebec', 'General/M&P')  11.9  11.9  11.9  11.9
# 18        ('New Brunswick', 'General/M&P/Investment')  13.0  12.0  11.0  10.0
# 20          ('Nova Scotia', 'General/M&P/Investment')  16.0  16.0  16.0  16.0
# 22  ('Prince Edward Island', 'General/Investment/M...  16.0  16.0  16.0  16.0
# 24  ('Newfoundland and Labrador', 'General/Investm...  14.0  14.0  14.0  14.0
# ...

# %%
filtered_df.reset_index(drop=True, inplace=True)
filtered_df
# Out:
#                                              Province  2009  2010  2011  2012  \
# 0               ('Federal', 'General/M&P/Investment')  19.0  18.0  16.5  15.0
# 1      ('British Columbia', 'General/M&P/Investment')  11.0  10.5  10.0  10.0
# 2               ('Alberta', 'General/M&P/Investment')  10.0  10.0  10.0  10.0
# 3              ('Saskatchewan', 'General/Investment')  12.0  12.0  12.0  12.0
# 4              ('Manitoba', 'General/M&P/Investment')  13.0  12.0  12.0  12.0
# 5                   ('Ontario', 'General/Investment')  14.0  12.0  11.5  11.5
# 6                           ('Quebec', 'General/M&P')  11.9  11.9  11.9  11.9
# 7         ('New Brunswick', 'General/M&P/Investment')  13.0  12.0  11.0  10.0
# 8           ('Nova Scotia', 'General/M&P/Investment')  16.0  16.0  16.0  16.0
# 9   ('Prince Edward Island', 'General/Investment/M...  16.0  16.0  16.0  16.0
# 10  ('Newfoundland and Labrador', 'General/Investm...  14.0  14.0  14.0  14.0
# ...

# %%
filtered_df.to_csv('big_non_manufacturing.csv', index=False)

# %%
df
# Out:
#                                              Province   2009   2010   2011  \
# 0               ('Federal', 'General/M&P/Investment')  19.00  18.00  16.50
# 1                       ('Federal', 'Small business')  11.00  11.00  11.00
# 2                    ('Federal', 'Investment - CCPC')  34.67  34.67  34.67
# 3      ('British Columbia', 'General/M&P/Investment')  11.00  10.50  10.00
# 4              ('British Columbia', 'Small business')   2.50   2.50   2.50
# 5               ('Alberta', 'General/M&P/Investment')  10.00  10.00  10.00
# 6                       ('Alberta', 'Small business')   3.00   3.00   3.00
# 7              ('Saskatchewan', 'General/Investment')  12.00  12.00  12.00
# 8                  ('Saskatchewan', 'Small business')   4.50   4.50   4.50
# 9                             ('Saskatchewan', 'M&P')  10.00  10.00  10.00
# 10             ('Manitoba', 'General/M&P/Investment')  13.00  12.00  12.00
# ...

# %%
import pandas as pd


def filter_small_rows(df):
    # Ensure the first column is treated as strings
    df.iloc[:, 0] = df.iloc[:, 0].astype(str)
    # Filter rows where the first column contains the word "General"
    filtered_df = df[df.iloc[:, 0].str.contains(r'\bSmall\b', case=False, na=False)]
    return filtered_df


filtered_small_df = filter_small_rows(df)
filtered_small_df
# Out:
#                                            Province  2009  2010  2011  2012  \
# 1                     ('Federal', 'Small business')  11.0  11.0  11.0  11.0
# 4            ('British Columbia', 'Small business')   2.5   2.5   2.5   2.5
# 6                     ('Alberta', 'Small business')   3.0   3.0   3.0   3.0
# 8                ('Saskatchewan', 'Small business')   4.5   4.5   4.5   2.0
# 11                   ('Manitoba', 'Small business')   1.0   1.0   0.0   0.0
# 13                    ('Ontario', 'Small business')   5.5   4.5   4.5   4.5
# 16                     ('Quebec', 'Small business')   8.0   8.0   8.0   8.0
# 19              ('New Brunswick', 'Small business')   5.0   5.0   5.0   4.5
# 21                ('Nova Scotia', 'Small business')   5.0   5.0   4.5   4.0
# 23       ('Prince Edward Island', 'Small business')   3.2   2.1   1.0   1.0
# 25  ('Newfoundland and Labrador', 'Small business')   5.0   4.0   4.0   4.0
# ...

# %%
# filtered_small_df.drop(17, inplace=True)
# filtered_small_df.reset_index(drop=True, inplace=True)
# filtered_small_df.drop(12, inplace=True)
# filtered_small_df

# %%
filtered_small_df.to_csv('small_non_manufacturing.csv', index=False)

# %%
import pandas as pd


def filter_mp_rows(df):
    # Ensure the first column is treated as strings
    df.iloc[:, 0] = df.iloc[:, 0].astype(str)
    # Filter rows where the first column contains the word "General"
    filtered_df = df[df.iloc[:, 0].str.contains(r'\bm&p\b', case=False, na=False)]
    return filtered_df


filtered_mp_df = filter_mp_rows(df)
filtered_mp_df
# Out:
#                                              Province  2009  2010  2011  2012  \
# 0               ('Federal', 'General/M&P/Investment')  19.0  18.0  16.5  15.0
# 3      ('British Columbia', 'General/M&P/Investment')  11.0  10.5  10.0  10.0
# 5               ('Alberta', 'General/M&P/Investment')  10.0  10.0  10.0  10.0
# 9                             ('Saskatchewan', 'M&P')  10.0  10.0  10.0  10.0
# 10             ('Manitoba', 'General/M&P/Investment')  13.0  12.0  12.0  12.0
# 14                                 ('Ontario', 'M&P')  12.0  10.0  10.0  10.0
# 15                          ('Quebec', 'General/M&P')  11.9  11.9  11.9  11.9
# 18        ('New Brunswick', 'General/M&P/Investment')  13.0  12.0  11.0  10.0
# 20          ('Nova Scotia', 'General/M&P/Investment')  16.0  16.0  16.0  16.0
# 22  ('Prince Edward Island', 'General/Investment/M...  16.0  16.0  16.0  16.0
# 26               ('Newfoundland and Labrador', 'M&P')   5.0   5.0   5.0   5.0
# ...

# %%
filtered_mp_df.to_csv('filtered_mp_df.csv', index=False)

# %%
# Create the two DataFrames based on the condition
small_filtered_mp_df = filtered_mp_df
big_filtered_mp_df = filtered_mp_df

# %%
# big_filtered_mp_df.drop([17, 30], inplace=True)
# big_filtered_mp_df.reset_index(drop=True, inplace=True)
# big_filtered_mp_df

# %%
big_filtered_mp_df.to_csv('big_manufacturing.csv', index=False)
big_filtered_mp_df.reset_index(drop=True, inplace=True)
big_filtered_mp_df
# Out:
#                                              Province  2009  2010  2011  2012  \
# 0               ('Federal', 'General/M&P/Investment')  19.0  18.0  16.5  15.0
# 1      ('British Columbia', 'General/M&P/Investment')  11.0  10.5  10.0  10.0
# 2               ('Alberta', 'General/M&P/Investment')  10.0  10.0  10.0  10.0
# 3                             ('Saskatchewan', 'M&P')  10.0  10.0  10.0  10.0
# 4              ('Manitoba', 'General/M&P/Investment')  13.0  12.0  12.0  12.0
# 5                                  ('Ontario', 'M&P')  12.0  10.0  10.0  10.0
# 6                           ('Quebec', 'General/M&P')  11.9  11.9  11.9  11.9
# 7         ('New Brunswick', 'General/M&P/Investment')  13.0  12.0  11.0  10.0
# 8           ('Nova Scotia', 'General/M&P/Investment')  16.0  16.0  16.0  16.0
# 9   ('Prince Edward Island', 'General/Investment/M...  16.0  16.0  16.0  16.0
# 10               ('Newfoundland and Labrador', 'M&P')   5.0   5.0   5.0   5.0
# ...

# %%
filtered_mp_df = pd.read_csv('filtered_mp_df.csv')
filtered_mp_df
# Out:
#                                              Province  2009  2010  2011  2012  \
# 0               ('Federal', 'General/M&P/Investment')  19.0  18.0  16.5  15.0
# 1      ('British Columbia', 'General/M&P/Investment')  11.0  10.5  10.0  10.0
# 2               ('Alberta', 'General/M&P/Investment')  10.0  10.0  10.0  10.0
# 3                             ('Saskatchewan', 'M&P')  10.0  10.0  10.0  10.0
# 4              ('Manitoba', 'General/M&P/Investment')  13.0  12.0  12.0  12.0
# 5                                  ('Ontario', 'M&P')  12.0  10.0  10.0  10.0
# 6                           ('Quebec', 'General/M&P')  11.9  11.9  11.9  11.9
# 7         ('New Brunswick', 'General/M&P/Investment')  13.0  12.0  11.0  10.0
# 8           ('Nova Scotia', 'General/M&P/Investment')  16.0  16.0  16.0  16.0
# 9   ('Prince Edward Island', 'General/Investment/M...  16.0  16.0  16.0  16.0
# 10               ('Newfoundland and Labrador', 'M&P')   5.0   5.0   5.0   5.0
# ...

# %%
# filtered_mp_df.drop([12, 6], inplace=True)
filtered_mp_df.reset_index(drop=True, inplace=True)
filtered_mp_df
# Out:
#                                              Province  2009  2010  2011  2012  \
# 0               ('Federal', 'General/M&P/Investment')  19.0  18.0  16.5  15.0
# 1      ('British Columbia', 'General/M&P/Investment')  11.0  10.5  10.0  10.0
# 2               ('Alberta', 'General/M&P/Investment')  10.0  10.0  10.0  10.0
# 3                             ('Saskatchewan', 'M&P')  10.0  10.0  10.0  10.0
# 4              ('Manitoba', 'General/M&P/Investment')  13.0  12.0  12.0  12.0
# 5                                  ('Ontario', 'M&P')  12.0  10.0  10.0  10.0
# 6                           ('Quebec', 'General/M&P')  11.9  11.9  11.9  11.9
# 7         ('New Brunswick', 'General/M&P/Investment')  13.0  12.0  11.0  10.0
# 8           ('Nova Scotia', 'General/M&P/Investment')  16.0  16.0  16.0  16.0
# 9   ('Prince Edward Island', 'General/Investment/M...  16.0  16.0  16.0  16.0
# 10               ('Newfoundland and Labrador', 'M&P')   5.0   5.0   5.0   5.0
# ...

# %%
filtered_mp_df.to_csv('small_manufacturing.csv', index=False)
